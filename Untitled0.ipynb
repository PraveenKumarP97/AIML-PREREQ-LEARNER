# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenKumarP97/AIML-PREREQ-LEARNER/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Praveen Kumar")
# Out:
# Praveen Kumar
